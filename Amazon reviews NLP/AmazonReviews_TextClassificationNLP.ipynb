# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

import nltk
nltk.download("punkt")
nltk.download("wordnet")
nltk.download("stopwords")

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence #unique id

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, Dropout, Embedding

import warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\SWARALI\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\SWARALI\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\SWARALI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_excel("amazonreviews.xlsx")
df.head()
# Out:
#                                        label\treview  \
# 0  pos\tStuning even for the non-gamer: This soun...
# 1  pos\tThe best soundtrack ever to anything.: I'...
# 2  pos\t"Amazing!: This soundtrack is my favorite...
# 3  pos\tExcellent Soundtrack: I truly like this s...
# 4                                      pos\tRemember
#
#                                           Unnamed: 1  \
# 0                                                NaN
# 1  but if you are going to buy any cd for this mu...
# 2  hands down. The intense sadness of ""Prisoners...
# 3                             Between Life and Death
# 4  Pull Your Jaw Off The Floor After Hearing it: ...
#
#                                           Unnamed: 2  \
# 0                                                NaN
# 1  this is the only one that I feel would be wort...
# 2                           Time of the Dreamwatch""
# 3                                 Forest Of Illusion
# 4  you know how divine the music is! Every single...
#
#                                           Unnamed: 3  \
# 0                                                NaN
# 1                                                NaN
# 2  and ""Chronomantique"" (indefinably remeniscen...
# 3                        Fortress of Ancient Dragons
# 4  it's that good! The greatest songs are without...
#
#                                           Unnamed: 4  \
# 0                                                NaN
# 1                                                NaN
# 2  probably the best of this composer's work (I h...
# 3                                      Lost Fragment
# 4                          Chrono Cross: Time's Scar
#
#                                   Unnamed: 5  \
# 0                                        NaN
# 1                                        NaN
# 2                   so I can't say for sure)
# 3  and Drowned Valley.Disk Two: The Draggons
# 4                 Magical Dreamers: The Wind
#
#                                  Unnamed: 6  \
# 0                                       NaN
# 1                                       NaN
# 2  and even if you've never played the game
# 3                            Galdorb - Home
# 4                                 The Stars
#
#                                           Unnamed: 7  \
# 0                                                NaN
# 1                                                NaN
# 2  it would be worth twice the price to buy it.I ...
# 3                                     Chronomantique
# 4  and the Sea and Radical Dreamers: Unstolen Jew...
#
#                                           Unnamed: 8 Unnamed: 9  ...  \
# 0                                                NaN        NaN  ...
# 1                                                NaN        NaN  ...
# 2                                                NaN        NaN  ...
# 3                                  Prisoners of Fate       Gale  ...
# 4  the best it can be. Yasunori Mitsuda just pour...        NaN  ...
#
#        Unnamed: 15     Unnamed: 16 Unnamed: 17  \
# 0              NaN             NaN         NaN
# 1              NaN             NaN         NaN
# 2              NaN             NaN         NaN
# 3  Dragon's Prayer  Tower Of Stars  Dragon God
# 4              NaN             NaN         NaN
#
#                                         Unnamed: 18  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3  and Radical Dreamers - Unstealable Jewel.Overall
# 4                                               NaN
#
#                                          Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 0                                                NaN         NaN         NaN
# 1                                                NaN         NaN         NaN
# 2                                                NaN         NaN         NaN
# 3  this is a excellent soundtrack and should be b...         NaN         NaN
# 4                                                NaN         NaN         NaN
#
#   Unnamed: 22 Unnamed: 23 Unnamed: 24
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   label	review  9999 non-null   object
#  1   Unnamed: 1    7747 non-null   object
#  2   Unnamed: 2    5943 non-null   object
#  3   Unnamed: 3    4402 non-null   object
#  4   Unnamed: 4    3266 non-null   object
#  5   Unnamed: 5    2480 non-null   object
#  6   Unnamed: 6    1812 non-null   object
#  7   Unnamed: 7    1319 non-null   object
#  8   Unnamed: 8    933 non-null    object
#  9   Unnamed: 9    633 non-null    object
#  10  Unnamed: 10   436 non-null    object
#  11  Unnamed: 11   307 non-null    object
#  12  Unnamed: 12   176 non-null    object
#  13  Unnamed: 13   130 non-null    object
#  14  Unnamed: 14   88 non-null     object
#  15  Unnamed: 15   46 non-null     object
#  16  Unnamed: 16   29 non-null     object
#  17  Unnamed: 17   17 non-null     object
#  18  Unnamed: 18   11 non-null     object
#  19  Unnamed: 19   8 non-null      object
#  20  Unnamed: 20   6 non-null      object
#  21  Unnamed: 21   2 non-null      object
#  22  Unnamed: 22   2 non-null      object
#  23  Unnamed: 23   1 non-null      float64
#  24  Unnamed: 24   1 non-null      object
# dtypes: float64(1), object(24)
# memory usage: 1.9+ MB
